# %% [markdown]
# # Exploratory Data Analysis - Prices
# This notebook visualizes the raw stock price data and computes baseline correlations.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print('Ready for EDA')
